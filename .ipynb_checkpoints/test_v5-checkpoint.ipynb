# %%
import tensorflow as tf
import os
import cv2
# Out:
# WARNING:tensorflow:From C:\Users\sgarr\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
data_dir = 'immagini'

# %%
image_exts = ['.jpeg', '.jpg', '.bmp', '.png']

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try:
            img = cv2.imread(image_path)
            file_ext = os.path.splitext(image_path)[1].lower()  
            if file_ext not in image_exts:
                print('Immagine con estensione non valida:', image_path)
                os.remove(image_path)  
        except Exception as e:
            print('Problemi con l\'immagine:', image_path)
# Out:
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\A-view-of-the-historic-centre-with-steep-steps-Perugia-Italy-rossiwrites.com_-1024x681.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\annucci-in-the-historic-centre-Perugia-Italy-rossiwrites.com-5-1024x681.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\Bergamo_Basilica-di-S.Maria-Maggiore-2_TOA.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\best-things-to-do-in-bergamo-main-image-hd-op.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\Boccadasse_Genova_Paolo-Margari-jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\centro-storico-di-torino-un-gioiello-da-scoprire-exclusive-brands-torino-cover-image-6.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\Cosa-vedere-a-Perugia-in-un-gorno-680x450.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\hotel-agostini---ravenna-citta-darte.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\hotel-agostini---ravenna.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\iStock-466191073.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\jesolo-1-900x800.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\jesolo-5.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\jesolo-alto-hotel-le-soleil-jesolo-1200x800.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\la-classifica-del-sole-24-ore-bergamo-vola-al-quinto-posto_u4yZhdB_original.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\la-spezia-cinque-terre-italy.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\Lido-di-Jesolo.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\mappa_spezia.gif
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\spiagge-lido-di-jesolo.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_esponenziale\spiaggia_jesolo2.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\agrigento-capitale-cultura-2025.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\banner-turismo-2022.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\Beborghi_agrigento_valle-dei-templi-2-scaled-jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\Beborghi_catania_tramonto-scaled-jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\best-things-to-do-in-agrigento-main-image-hd-op.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\cosa-vedere-a-copenhagen-copertina-mobile.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\cosa-vedere-Marrakech-1.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\Danimarca_6738.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\Flag_of_Damascus.svg
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\Things-to-do-in-Tripoli-1080x675.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_gaussiano\vivere-provincia-bologna.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\cammello-1170x730.gif
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\eyJpZGVudGlmaWVyIjo0MjAzNTQsInR5cGUiOiJhc3NldCJ9.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\index.gif
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\Los-Angeles.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\One-day-in-Las-Vegas-itinerary.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\p0gzbrt0.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\PemKKTuYEVhgxdGMN6uX7pg1KW6tq0H1WNd7xaAD.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\pietrelcina-cose-da-vedere-1.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\tunisi-porta-medina.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\tunisi-sidi-bou-said-entrata.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\tunisi-viale-principale.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\tunisia_it-IT.webp
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector10.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector11.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector12.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector13.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector2.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector3.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector4.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector5.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector6.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector7.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector8.svg
# Immagine con estensione non valida: immagini\immagini_rumore_non_uniforme\vector9.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\075645d8053f4be5887cf318cef74524.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\1783-12514288.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\nirvana-live-oct-1993-u-billboard-1548-770x470-1.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\port_moresby.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\RC_33_Nirvana_Cover_U1_web-gross_1024x1024_2x_4500bfec-03ca-4ab9-809d-2efccd0f0658.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\s-l1200.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\s-l12002.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\san-marco-venezia-1536x1152.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\syd.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\trinidad-1-1679302593.profileImage.2x-jpg-webp-scaled.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector10.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector11.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector12.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector13.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector2.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector3.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector4.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector5.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector6.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector7.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector8.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\vector9.svg
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\video-anteprima-daft-punk.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\View-of-Sydney-Harbour-Bridge-and-the-city.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_salepepe\view-port-moresby-papua-new-guinea-pacific-13224497.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\4c81cf_e45288d38a2b43af824394c7efd8eebdmv2.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\63eb683b66203bcb0a15bd30_Caparezza208.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\7eb1d5ffd73eb5895aa14484c017fbaf93-the-weeknd-2.rsquare.w700.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\Caparezza3.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\caparezza_acufene_prisoner_709-696x435.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\crediti-ansa-caparezza.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\Diddy-The-Weeknd-2015-billboard-1548.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\Il-ritorno-alle-origini-dei-Linkin-Park.jpg.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\kanye-west-inter-atletico-madrid-san-siro-1024x677.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\kanye-west.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\kanye-west3.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\original.webp
# Immagine con estensione non valida: immagini\immagini_rumore_uniforme\timothEe-chalamet-52227-320x450.webp

# %%
import numpy as np
import cv2
import os
import random

def aggiungi_rumore_uniforme_periodico(immagine, periodo=10):
    rumore_uniforme = np.random.randint(0, 256, size=immagine.shape, dtype=np.uint8)
    for i in range(0, immagine.shape[0], periodo):
        for j in range(0, immagine.shape[1], periodo):
            immagine[i:i+periodo, j:j+periodo] += rumore_uniforme[i:i+periodo, j:j+periodo]
    return np.clip(immagine, 0, 255).astype(np.uint8)

# Percorso della directory contenente le immagini originali
directory_immagini_originali = "C:/Users/sgarr/Desktop/progettoMultimedia_v2/immagini/immagini_rumore_uniforme"

# Percorso della directory in cui salvare le immagini con rumore
directory_immagini_con_rumore = "C:/Users/sgarr/Desktop/progettoMultimedia_v2/immagini_v2/immagini_rumorose_uniforme"

# Itera su ogni immagine nella directory delle immagini originali
for filename in os.listdir(directory_immagini_originali):
    # Carica l'immagine originale
    percorso_immagine_originale = os.path.join(directory_immagini_originali, filename)
    immagine_originale = cv2.imread(percorso_immagine_originale)
    if immagine_originale is None:
        print(f"Errore: impossibile leggere l'immagine {percorso_immagine_originale}")
    else: 
        immagine_con_rumore = aggiungi_rumore_uniforme_periodico(immagine_originale)
        if immagine_con_rumore is None:
            print(f"Errore: impossibile elaborare l'immagine {percorso_immagine_originale}")
        else:
            if not os.path.exists(directory_immagini_con_rumore):
                os.makedirs(directory_immagini_con_rumore)
            percorso_immagine_con_rumore = os.path.join(directory_immagini_con_rumore, filename)
            cv2.imwrite(percorso_immagine_con_rumore, immagine_con_rumore)

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
# Out:
# WARNING:tensorflow:From C:\Users\sgarr\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Permette di creare una pipeline in maniera efficiente, distinguendo i diversi tipi di rumore.
data = tf.keras.utils.image_dataset_from_directory('immagini_v2')
# Out:
# Found 5249 files belonging to 5 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
batch[0].shape
# Out:
# (32, 256, 256, 3)

# %%
# Operazione per scalare i valori tra 0 e 1
data = data.map(lambda x, y: (x/255, y))

# %%
scaled_iterator = data.as_numpy_iterator()

# %%
batch = scaled_iterator.next()

# %%
fig, ax = plt.subplots(ncols=5, figsize=(20,20))
for idx, img in enumerate(batch[0][:5]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])
    
# Etichetta 0: esponenziale
# Etichetta 1: gaussiano
# Etichetta 2: non uniforme
# Etichetta 3: sale e pepe
# Etichetta 4: uniforme

# %%
len(data)
# Out:
# 165

# %%
train_size = int(len(data)*.6)  
val_size = int(len(data)*.2)     
test_size = int(len(data)*.2)

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %%
from keras.models import Sequential
from keras import layers
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# %%
model = Sequential()

# %%
from tensorflow.keras import regularizers

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# Riduci la dimensione dei layer densi
model.add(layers.Flatten())

model.add(layers.Dense(64, activation='relu'))
# Aggiungi Dropout
model.add(layers.Dropout(0.5))

# Aggiungi il layer di output
model.add(layers.Dense(5, activation='softmax'))

# %%
learning_rate = 0.001
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 254, 254, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 127, 127, 32)      0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 62, 62, 64)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_5 (MaxPoolin  (None, 30, 30, 128)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 115200)            0
#
#  dense_2 (Dense)             (None, 64)                7372864
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 7466437 (28.48 MB)
# Trainable params: 7466437 (28.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
logdir = 'logs'

# %%
# Salvo passo per passo il modello, posso tornare indietro per verificare come performava
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\sgarr\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\sgarr\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 99/99 [==============================] - 287s 3s/step - loss: 1.2583 - accuracy: 0.4463 - val_loss: 0.8361 - val_accuracy: 0.7235
# Epoch 2/20
# 99/99 [==============================] - 288s 3s/step - loss: 0.9362 - accuracy: 0.5824 - val_loss: 0.6933 - val_accuracy: 0.7585
# Epoch 3/20
# 99/99 [==============================] - 275s 3s/step - loss: 0.7827 - accuracy: 0.6622 - val_loss: 0.5759 - val_accuracy: 0.8021
# Epoch 4/20
# 99/99 [==============================] - 278s 3s/step - loss: 0.6510 - accuracy: 0.7172 - val_loss: 0.5068 - val_accuracy: 0.8191
# Epoch 5/20
# 99/99 [==============================] - 272s 3s/step - loss: 0.6099 - accuracy: 0.7364 - val_loss: 0.5489 - val_accuracy: 0.7945
# Epoch 6/20
# 99/99 [==============================] - 271s 3s/step - loss: 0.5522 - accuracy: 0.7828 - val_loss: 0.5149 - val_accuracy: 0.7680
# Epoch 7/20
# 99/99 [==============================] - 274s 3s/step - loss: 0.4762 - accuracy: 0.8046 - val_loss: 0.3202 - val_accuracy: 0.8902
# Epoch 8/20
# 99/99 [==============================] - 277s 3s/step - loss: 0.4362 - accuracy: 0.8422 - val_loss: 0.3626 - val_accuracy: 0.8655
# Epoch 9/20
# 99/99 [==============================] - 277s 3s/step - loss: 0.3899 - accuracy: 0.8602 - val_loss: 0.2881 - val_accuracy: 0.8920
# Epoch 10/20
# 99/99 [==============================] - 275s 3s/step - loss: 0.4180 - accuracy: 0.8415 - val_loss: 0.3038 - val_accuracy: 0.8930
# Epoch 11/20
# 99/99 [==============================] - 278s 3s/step - loss: 0.3285 - accuracy: 0.8879 - val_loss: 0.2995 - val_accuracy: 0.8845
# Epoch 12/20
# 99/99 [==============================] - 278s 3s/step - loss: 0.3431 - accuracy: 0.8826 - val_loss: 0.3381 - val_accuracy: 0.8703
# Epoch 13/20
# 99/99 [==============================] - 275s 3s/step - loss: 0.2628 - accuracy: 0.9126 - val_loss: 0.2353 - val_accuracy: 0.9072
# Epoch 14/20
# 99/99 [==============================] - 276s 3s/step - loss: 0.2462 - accuracy: 0.9148 - val_loss: 0.2809 - val_accuracy: 0.9072
# Epoch 15/20
# 99/99 [==============================] - 276s 3s/step - loss: 0.2845 - accuracy: 0.9031 - val_loss: 0.2897 - val_accuracy: 0.9119
# Epoch 16/20
# 99/99 [==============================] - 275s 3s/step - loss: 0.3029 - accuracy: 0.8968 - val_loss: 0.2062 - val_accuracy: 0.9290
# Epoch 17/20
# 99/99 [==============================] - 276s 3s/step - loss: 0.3155 - accuracy: 0.8876 - val_loss: 0.2661 - val_accuracy: 0.9195
# Epoch 18/20
# 99/99 [==============================] - 275s 3s/step - loss: 0.2194 - accuracy: 0.9283 - val_loss: 0.2295 - val_accuracy: 0.9309
# Epoch 19/20
# 99/99 [==============================] - 275s 3s/step - loss: 0.1924 - accuracy: 0.9324 - val_loss: 0.2444 - val_accuracy: 0.9242
# Epoch 20/20
# 99/99 [==============================] - 273s 3s/step - loss: 0.2781 - accuracy: 0.9018 - val_loss: 0.4312 - val_accuracy: 0.8551

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
from tensorflow.keras.metrics import Precision, Recall, F1Score, Accuracy, FalsePositives, AUC

# %%
pre = Precision()
re = Recall()
f1 = F1Score()
acc = Accuracy()
fp = FalsePositives()
auc = AUC()

# %%
for batch in test.as_numpy_iterator():
    X, y = batch
    yhat = model.predict(X)
    
    y_one_hot = tf.one_hot(y, 5)
    
    pre.update_state(y_one_hot, yhat)
    re.update_state(y_one_hot, yhat)
    f1.update_state(y_one_hot, yhat)
    acc.update_state(y_one_hot, yhat)
    fp.update_state(y_one_hot, yhat)
    auc.update_state(y_one_hot, yhat)
# Out:
# 1/1 [==============================] - 1s 894ms/step
# 1/1 [==============================] - 1s 563ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 516ms/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 0s 486ms/step
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 415ms/step
# 1/1 [==============================] - 0s 432ms/step
# 1/1 [==============================] - 0s 453ms/step
# 1/1 [==============================] - 0s 408ms/step
# 1/1 [==============================] - 0s 406ms/step
# 1/1 [==============================] - 1s 519ms/step
# 1/1 [==============================] - 1s 553ms/step
# 1/1 [==============================] - 1s 551ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 517ms/step
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 1s 543ms/step
# 1/1 [==============================] - 1s 550ms/step
# 1/1 [==============================] - 1s 532ms/step
# 1/1 [==============================] - 1s 569ms/step
# 1/1 [==============================] - 1s 535ms/step
# 1/1 [==============================] - 0s 438ms/step
# 1/1 [==============================] - 0s 447ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 314ms/step
# 1/1 [==============================] - 0s 344ms/step
# 1/1 [==============================] - 0s 329ms/step
# 1/1 [==============================] - 0s 334ms/step
# 1/1 [==============================] - 0s 360ms/step
# 1/1 [==============================] - 0s 342ms/step
# 1/1 [==============================] - 0s 175ms/step

# %%
print(f'Precision:{pre.result().numpy()}, Recall:{re.result().numpy()}, F1:{f1.result().numpy()}, Accuracy:{acc.result().numpy()}, FalsePositives:{fp.result().numpy()}, AUC:{auc.result().numpy()}')
# Out:
# Precision:0.8325074315071106, Recall:0.8195121884346008, F1:[0.93670887 0.8310503  0.6975308  0.8207792  0.8110236 ], Accuracy:0.08312194794416428, FalsePositives:169.0, AUC:0.9644588828086853

# %%
import cv2

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

img_path = 'verona_con_rumore_uniforme.jpg'
img = tf.io.read_file(img_path)
img = tf.image.decode_jpeg(img, channels=3)  # Decodifica l'immagine in RGB
resized_img = tf.image.resize(img, (256, 256))

# Visualizza l'immagine
plt.imshow(resized_img / 255.0)  # Normalizza i valori dei pixel tra 0 e 1
plt.axis('off')  # Nasconde gli assi
plt.show()

# %%
yhat = model.predict(np.expand_dims(resized_img/255, 0))
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %%
yhat
# Out:
# array([[3.3575401e-04, 4.8563528e-05, 3.4815827e-01, 2.3154060e-05,
#         6.5143418e-01]], dtype=float32)

# %%
from tensorflow.keras.models import load_model

model.save('models/modellov5_rumori.h5')
# Out:
# C:\Users\sgarr\anaconda3\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
